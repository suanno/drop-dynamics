# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def w(h):
    return (h**(-5)/5 + h**(-2)/2)
def dw(h):
    return (- h**(-6) + h**(-3))
def ddw(h):
    return (6*h**(-7) - 3*h**(-4))

# %% [markdown]
# # Periodic BC

# %%
# Continuation to compute h0in for different values of hmax or h0out
data = np.loadtxt(
    "continuation/1D_c0_continuation_pbc.txt",
    delimiter=',',
    unpack=True
)
numrows = len(data[0,:])
K = data[1:, numrows-1]
I = data[1:, numrows-2]
Omega = data[1:, numrows-3]
V = data[1:, numrows-4]
h0out_formula = data[1:, numrows-5]
h0out_lim = data[1:, numrows-6]
hmax = data[1:, numrows-7]

# %%
plt.plot(hmax,h0out_lim-1, label='$H_0^{\\mathrm{in}}|_{\\partial\\Omega}$', color='black')
plt.plot(hmax,h0out_formula-1, label='Formula from $H_0^{\\mathrm{out}}$', color='black',ls='--')
plt.xlim(2,6)
plt.ylim(0,0.1)
plt.xlabel('$H_{\\mathrm{max}}$')
plt.ylabel('$H_0^{\\mathrm{out}}-1$')
plt.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 6))
from matplotlib.ticker import FormatStrFormatter


# Bottom x-axis
ax.plot(hmax, Omega, label=r'$\Omega$',color='red')
ax.semilogy(hmax,I*(dw(h0out_lim)+h0out_lim*ddw(h0out_lim)), label='$I \\cdot \\partial_H(H\\partial_H \\omega)^{\\mathrm{out}}$', color='red',ls='--')
ax.plot(hmax, V,     label=r'$V$',color='blue')
ax.plot(hmax, I,     label=r'$I$',color='blue',ls='--')
ax.plot(hmax, K,     label=r'$K$',color='black',lw=1)

ax.set_xlabel(r'$h_{\max}$')
"""
# Top x-axis
ax_top = ax.twiny()

ax_top.set_xlim(ax.get_xlim())
n_ticks = 10
idx = np.linspace(0, len(h0out_lim) - 1, n_ticks, dtype=int)

ax_top.set_xticks(h0out_lim[idx]-1)
ax_top.set_xticklabels(h0out_lim[idx]-1)
ax_top.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
"""
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_xlabel(r'$H_{\mathrm{max}}$')
ax.set_xlim(2,6)
ax.set_ylim(1,100)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20700/1114198830.py:25: SyntaxWarning: invalid escape sequence '\m'
#   ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
# (1, 100)

# %% [markdown]
# # Neumann BC

# %%
# Continuation to compute h0in for different values of hmax or h0out
data = np.loadtxt(
    "continuation/1D_c0_continuation_nbc.txt",
    delimiter=',',
    unpack=True
)
numrows = len(data[0,:])
K = data[1:, numrows-1]
I = data[1:, numrows-2]
Omega = data[1:, numrows-3]
V = data[1:, numrows-4]
h0out_formula = data[1:, numrows-5]
h0out_lim = data[1:, numrows-6]
hmax = data[1:, numrows-7]

# %%
plt.plot(hmax,h0out_lim-1, label='$H_0^{\\mathrm{in}}|_{\\partial\\Omega}$', color='black')
plt.plot(hmax,h0out_formula-1, label='Formula from $H_0^{\\mathrm{out}}$', color='black',ls='--')
plt.xlim(2,6)
plt.ylim(0,0.1)
plt.xlabel('$H_{\\mathrm{max}}$')
plt.ylabel('$H_0^{\\mathrm{out}}-1$')
plt.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 6))
from matplotlib.ticker import FormatStrFormatter


# Bottom x-axis
ax.plot(hmax, Omega, label=r'$\Omega$',color='red')
ax.semilogy(hmax,I*(dw(h0out_lim)+h0out_lim*ddw(h0out_lim)), label='$I \\cdot \\partial_H(H\\partial_H \\omega)^{\\mathrm{out}}$', color='red',ls='--')
ax.plot(hmax, V,     label=r'$V$',color='blue')
ax.plot(hmax, I,     label=r'$I$',color='blue',ls='--')
ax.plot(hmax, K,     label=r'$K$',color='black',lw=1)

ax.set_xlabel(r'$h_{\max}$')
"""
# Top x-axis
ax_top = ax.twiny()

ax_top.set_xlim(ax.get_xlim())
n_ticks = 10
idx = np.linspace(0, len(h0out_lim) - 1, n_ticks, dtype=int)

ax_top.set_xticks(h0out_lim[idx]-1)
ax_top.set_xticklabels(h0out_lim[idx]-1)
ax_top.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
"""
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_xlabel(r'$H_{\mathrm{max}}$')
ax.set_xlim(2,6)
ax.set_ylim(1,100)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20700/1114198830.py:25: SyntaxWarning: invalid escape sequence '\m'
#   ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
# (1, 100)

# %%
plt.plot(h0out_lim)

# %%
# Critical radius in the parabolic approximation


fig, ax = plt.subplots(figsize=(9, 6))
from matplotlib.ticker import FormatStrFormatter


# Bottom x-axis
tanTheta = np.sqrt(3/5)
Delta = 4*((hmax-h0out_lim)**2+tanTheta*V/6)
R1 = 6*(2*(hmax-h0out_lim)+np.sqrt(Delta))/(2*tanTheta) 
R2 = 6*(2*(hmax-h0out_lim)-np.sqrt(Delta))/(2*tanTheta) 
ax.plot(hmax,R1,color='black')
ax.plot(hmax,R2,color='black')
ax.axvline(4.75,ls='--',color='black')
ax.set_xlabel(r'$h_{\max}$')
ax.set_ylabel(r'$R$')
"""
# Top x-axis
ax_top = ax.twiny()

ax_top.set_xlim(ax.get_xlim())
n_ticks = 10
idx = np.linspace(0, len(h0out_lim) - 1, n_ticks, dtype=int)

ax_top.set_xticks(h0out_lim[idx]-1)
ax_top.set_xticklabels(h0out_lim[idx]-1)
ax_top.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
"""
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_xlabel(r'$H_{\mathrm{max}}$')
ax.set_xlim(2,6)
ax.set_ylim(-10,80)
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20700/102058899.py:30: SyntaxWarning: invalid escape sequence '\m'
#   ax_top.set_xlabel(r'$H_0^{\mathrm{out}}-1$')
# /tmp/ipykernel_20700/102058899.py:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# (-10.0, 80.0)
