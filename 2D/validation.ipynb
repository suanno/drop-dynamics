# %%
# %run -i time_solver.py
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /data2To/rsuanno-local/drop-dynamics/2D/time_solver.py:131
#     129 problem.max_permitted_error = 0.0005
#     130 problem.min_permitted_error = 0.00005
# --> 131 problem.run(endtime=1e2, startstep=1, outstep=True, temporal_error=1, spatial_adapt=problem.max_refinement_level)
#     133 #problem.solve()  # Solve the problem
#     134 print(problem.get_mesh("domain").evaluate_all_observables())
#
# File ~/.local/lib/python3.12/site-packages/pyoomph/generic/problem.py:5179, in Problem.run(self, endtime, timestep, outstep, numouts, out_initially, temporal_error, outstep_relative_to_zero, spatial_adapt, startstep, maxstep, newton_solver_tolerance, do_not_set_IC, globally_convergent_newton, max_newton_iterations, starttime, suppress_resolve_after_adapt, max_newton_to_increase_time_step)
# ...
